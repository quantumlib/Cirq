# %%
import cirq
from cirq_superstaq import Service, AceCRPlusMinus

# %%
service = Service(api_key="YOUR API KEY")

# %%
qubits = cirq.LineQubit.range(2)

# %%
circuit = cirq.Circuit(AceCRPlusMinus(qubits[0], qubits[1]))

# %%
circuit
# Out:
# 0: ───AceCR+-(Z side)───
#       │
# 1: ───AceCR+-(X side)───

# %%
out = service.ibmq_compile(circuit, target="ibmq_jakarta")

# %%
out.draw()

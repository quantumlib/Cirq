# %% [markdown]
# # Running the Quantum Volume Algorithm
# This example walks through the steps of running the quantum volume algorithm on square matrices. It is intended to mirror Algorithm 1 of https://arxiv.org/pdf/1811.12926.pdf. In general, we will generate a model circuit, classically compute its Heavy Output Group, then run various samplers (currently, ideal and noisy simulators) to evaluate how often they generate Heavy results.

# %%
from examples.advanced import quantum_volume
import imp # TODO remove
imp.reload(quantum_volume) # TODO remove
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# Some set-up variables. Feel free to play with these.
num_repetitions = 10 # This is supposed to be >= 100.
depths = range(2, 5) # The depths and number of qubits

# Keep track of the ideal and noisy probabilities.
average_ideals = []
average_noisies = []

for depth in depths:
    num_qubits = depth # Square matrix.
    print("Running simulation with %s qubits and a depth of %s" % (num_qubits, depth))
    average_ideal = 0
    average_noisy = 0
    for i in range(num_repetitions):
        print("    Repetition %s of %s" % (str(i + 1), str(num_repetitions)))
        # Generate a model circuit.
        model_circuit = quantum_volume.generate_model_circuit(
            num_qubits, depth, random_state=np.random.RandomState()
        )
        # Compute its heavy set.
        heavy_set = quantum_volume.compute_heavy_set(model_circuit)
        print("        Heavy Set:", heavy_set)
        
        # Run an ideal simulator over the model circuit.
        ideal = quantum_volume.sample_heavy_set(model_circuit, heavy_set)
        average_ideal += ideal
        print("        Ideal simulation HOG probability: ", ideal)

        # Run a noisy simulator over the model circuit.
        noisy = quantum_volume.sample_heavy_set(model_circuit, heavy_set, sampler=cirq.DensityMatrixSimulator(noise=cirq.ConstantQubitNoiseModel(qubit_noise_gate=cirq.DepolarizingChannel(p=0.005))))
        print("        Noisy simulation HOG probability: ", noisy)
        average_noisy += noisy
        
        # TODO: The next steps are to compile the model circuit and run it on various devices.

    # Compute the average performance over the total number of runs.
    average_ideal /= num_repetitions
    average_noisy /= num_repetitions
    print("    Average ideal HOG probability:", average_ideal)
    print("    Average noisy HOG probability:", average_noisy)
    average_ideals.append(average_ideal)
    average_noisies.append(average_noisy)

# Create the chart. Note that we try to make it look as similar
# as possible to Figure 2 in https://arxiv.org/pdf/1811.12926.pdf.
fig, axs = plt.subplots()
axs.scatter(depths, average_ideals, marker='+', c='tab:green', label='Ideal')
axs.scatter([d + .1 for d in depths], average_noisies, c='tab:red', label='Noisy')
# Line markers for asymptotic ideal heavy output probability and the ideal Heavy Output Generation threshold.
axs.hlines((1 + np.log(2)) / 2, 0, 100, colors=['tab:green'], label='Asymptotic ideal', linestyles='dashed')
axs.hlines(2/3, 0, 100, label='HOG threshold', linestyles='dotted')
# Making the plot look consistent.
axs.set_ybound(0.4, 1)
axs.set_xbound(1.5, 4.5)
axs.xaxis.set_major_locator(plt.MultipleLocator(1))
axs.set_xlabel("width/depth of model circuit m=d")
axs.set_ylabel("est. heavy output probability h(d)")
fig.suptitle('Experimental data for square quantum volume circuits')
axs.legend(loc='lower left')
plt.show()
# Out:
# Running simulation with 2 qubits and a depth of 2
#     Repetition 1 of 10
#         Heavy Set: [0, 1]
#         Ideal simulation HOG probability:  0.764
#         Noisy simulation HOG probability:  0.704
#     Repetition 2 of 10
#         Heavy Set: [0, 3]
#         Ideal simulation HOG probability:  0.819
#         Noisy simulation HOG probability:  0.759
#     Repetition 3 of 10
#         Heavy Set: [0, 1]
#         Ideal simulation HOG probability:  0.656
#         Noisy simulation HOG probability:  0.608
#     Repetition 4 of 10
#         Heavy Set: [1, 3]
#         Ideal simulation HOG probability:  0.698
#         Noisy simulation HOG probability:  0.658
#     Repetition 5 of 10
#         Heavy Set: [1, 3]
#         Ideal simulation HOG probability:  0.919
#         Noisy simulation HOG probability:  0.876
#     Repetition 6 of 10
#         Heavy Set: [1, 2]
#         Ideal simulation HOG probability:  0.766
#         Noisy simulation HOG probability:  0.721
#     Repetition 7 of 10
#         Heavy Set: [0, 1]
#         Ideal simulation HOG probability:  0.819
#         Noisy simulation HOG probability:  0.73
#     Repetition 8 of 10
#         Heavy Set: [1, 3]
#         Ideal simulation HOG probability:  0.649
#         Noisy simulation HOG probability:  0.634
#     Repetition 9 of 10
#         Heavy Set: [1, 2]
#         Ideal simulation HOG probability:  0.96
#         Noisy simulation HOG probability:  0.865
#     Repetition 10 of 10
#         Heavy Set: [0, 1]
#         Ideal simulation HOG probability:  0.872
#         Noisy simulation HOG probability:  0.785
#     Average ideal HOG probability: 0.7922
#     Average noisy HOG probability: 0.734
# Running simulation with 3 qubits and a depth of 3
#     Repetition 1 of 10
#         Heavy Set: [1, 3, 4, 5]
#         Ideal simulation HOG probability:  0.854
#         Noisy simulation HOG probability:  0.761
#     Repetition 2 of 10
#         Heavy Set: [1, 4, 6, 7]
#         Ideal simulation HOG probability:  0.818
#         Noisy simulation HOG probability:  0.753
#     Repetition 3 of 10
#         Heavy Set: [1, 3, 5, 6]
#         Ideal simulation HOG probability:  0.903
#         Noisy simulation HOG probability:  0.813
#     Repetition 4 of 10
#         Heavy Set: [4, 5, 6, 7]
#         Ideal simulation HOG probability:  0.864
#         Noisy simulation HOG probability:  0.796
#     Repetition 5 of 10
#         Heavy Set: [1, 2, 3, 4]
#         Ideal simulation HOG probability:  0.878
#         Noisy simulation HOG probability:  0.746
#     Repetition 6 of 10
#         Heavy Set: [0, 2, 5, 6]
#         Ideal simulation HOG probability:  0.936
#         Noisy simulation HOG probability:  0.806
#     Repetition 7 of 10
#         Heavy Set: [1, 3, 4, 5]
#         Ideal simulation HOG probability:  0.859
#         Noisy simulation HOG probability:  0.755
#     Repetition 8 of 10
#         Heavy Set: [1, 2, 5, 6]
#         Ideal simulation HOG probability:  0.688
#         Noisy simulation HOG probability:  0.618
#     Repetition 9 of 10
#         Heavy Set: [0, 1]
#         Ideal simulation HOG probability:  0.934
#         Noisy simulation HOG probability:  0.797
#     Repetition 10 of 10
#         Heavy Set: [1, 4, 5, 6]
#         Ideal simulation HOG probability:  0.713
#         Noisy simulation HOG probability:  0.644
#     Average ideal HOG probability: 0.8446999999999999
#     Average noisy HOG probability: 0.7489000000000001
# Running simulation with 4 qubits and a depth of 4
#     Repetition 1 of 10
#         Heavy Set: [0, 5, 7, 8, 9, 10, 14, 15]
#         Ideal simulation HOG probability:  0.775
#         Noisy simulation HOG probability:  0.648
#     Repetition 2 of 10
#         Heavy Set: [1, 4, 6, 7, 11, 12, 14, 15]
#         Ideal simulation HOG probability:  0.842
#         Noisy simulation HOG probability:  0.746
#     Repetition 3 of 10
#         Heavy Set: [0, 4, 8, 9, 10, 11, 14, 15]
#         Ideal simulation HOG probability:  0.802
#         Noisy simulation HOG probability:  0.725
#     Repetition 4 of 10
#         Heavy Set: [0, 1, 2, 3, 10, 11, 12, 15]
#         Ideal simulation HOG probability:  0.822
#         Noisy simulation HOG probability:  0.692
#     Repetition 5 of 10
#         Heavy Set: [0, 2, 3, 6, 8, 11, 12, 14]
#         Ideal simulation HOG probability:  0.936
#         Noisy simulation HOG probability:  0.748
#     Repetition 6 of 10
#         Heavy Set: [0, 4, 5, 7, 9, 11, 13, 15]
#         Ideal simulation HOG probability:  0.763
#         Noisy simulation HOG probability:  0.654
#     Repetition 7 of 10
#         Heavy Set: [0, 1, 3, 6, 7, 13, 14, 15]
#         Ideal simulation HOG probability:  0.88
#         Noisy simulation HOG probability:  0.722
#     Repetition 8 of 10
#         Heavy Set: [1, 2, 6, 8, 10, 12, 13, 14]
#         Ideal simulation HOG probability:  0.839
#         Noisy simulation HOG probability:  0.728
#     Repetition 9 of 10
#         Heavy Set: [2, 3, 6, 7, 8, 9, 10, 14]
#         Ideal simulation HOG probability:  0.825
#         Noisy simulation HOG probability:  0.687
#     Repetition 10 of 10
#         Heavy Set: [4, 7, 8, 9, 10, 11, 14, 15]
#         Ideal simulation HOG probability:  0.858
#         Noisy simulation HOG probability:  0.734
#     Average ideal HOG probability: 0.8342
#     Average noisy HOG probability: 0.7084

# %%
import numpy as np 
import scipy as sp 
import cirq

# %%
np.linalg?

# %%
np?

# %%
np.arctan2?

# %%
x = np.array([-1j, 1, 1, 1j])
y = np.array([-1j, 3j, 1, 1j])
np.arctan2(np.linalg.norm(x),np.linalg.norm(y))
# Out:
# 0.5235987755982989

# %%
U = cirq.testing.random_unitary(8)
U
# Out:
# array([[-0.0023416 +0.0198146j ,  0.31291811-0.0928759j ,
#         -0.24925944-0.10489372j, -0.53030765-0.3530056j ,
#          0.29683525+0.23772689j,  0.14958884-0.38873227j,
#          0.01962168-0.06832083j, -0.08876166-0.28816643j],
#        [-0.11782617-0.11485474j,  0.01441705+0.06307221j,
#         -0.13628065+0.57019616j, -0.08068403-0.01556074j,
#         -0.31595662+0.30480234j, -0.25090207+0.19563679j,
#         -0.09317858+0.27503726j,  0.04626818-0.4877132j ],
#        [-0.1160137 +0.09810891j,  0.05689942+0.35141577j,
#          0.05262297-0.27272674j,  0.13927293+0.14306548j,
#          0.10067678+0.20092873j, -0.4361721 +0.05182871j,
#         -0.24731456-0.57303297j, -0.12399692-0.29124584j],
#        [-0.04910888+0.1332558j ,  0.42731408-0.16788742j,
#          0.15607997-0.25239412j, -0.30949701+0.36332286j,
#         -0.04052497+0.19269387j, -0.08242435+0.30676508j,
#          0.04126705+0.09580903j,  0.54394894+0.08220388j],
# ...

# %%
cirq.bidiagonalize_unitary_with_special_orthogonals(U)
# Out:
# (array([[ 0.4562113 , -0.05634121, -0.13567677,  0.6796015 , -0.27621843,
#           0.31980196, -0.34882194,  0.09046477],
#         [-0.44384572,  0.01780225,  0.35612936, -0.00895563, -0.27407929,
#          -0.19407779, -0.57531301,  0.48166899],
#         [ 0.21767298, -0.47179583, -0.30623562, -0.57210204, -0.32533829,
#           0.03775074, -0.39687865, -0.21015084],
#         [-0.04973498, -0.50381577, -0.03447604,  0.00211045,  0.70351265,
#           0.31590223, -0.1408486 ,  0.35768766],
#         [ 0.69662953,  0.05004831,  0.60871689, -0.20836242,  0.15658122,
#          -0.24156731, -0.05653596,  0.11037462],
#         [-0.03269431, -0.37264814, -0.11498774,  0.37927452,  0.18045323,
#          -0.76624448, -0.1131618 , -0.26550619],
#         [-0.22304075, -0.02766855,  0.478308  ,  0.0902956 ,  0.14323584,
#           0.31900869, -0.30157227, -0.70663042],
#         [ 0.09438402,  0.61477646, -0.38374191, -0.12385087,  0.41256675,
# ...
